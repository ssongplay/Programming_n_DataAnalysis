# %% [markdown]
# # CHAPTER06 문자열

# %%
# 6-1 yesterday.py
f = open("yesterday.txt", 'r')
yesterday_lyrics = f.readlines()
f.close

contents = ""
for line in yesterday_lyrics:
    contents = contents + line.strip() + "\n"
    print(contents)
    
n_of_yesterday = contents.upper().count("YESTERDAY")
print("Number of a Word 'Yesterday'", n_of_yesterday)
# Out:
# Yesterday all my troubles
#
# Yesterday all my troubles
# seemed so far away.
#
# Yesterday all my troubles
# seemed so far away.
# Now it looks
#
# Yesterday all my troubles
# seemed so far away.
# Now it looks
# as though they're here to stay.
#
# Yesterday all my troubles
# seemed so far away.
# Now it looks
# as though they're here to stay.
# Oh, I believe in yesterday.
#
# Yesterday all my troubles
# seemed so far away.
# Now it looks
# as though they're here to stay.
# Oh, I believe in yesterday.
#
#
# Yesterday all my troubles
# seemed so far away.
# Now it looks
# as though they're here to stay.
# Oh, I believe in yesterday.
#
# Suddenly I'm not half
#
# Yesterday all my troubles
# seemed so far away.
# Now it looks
# as though they're here to stay.
# Oh, I believe in yesterday.
#
# Suddenly I'm not half
# the man I used to be.
#
# Yesterday all my troubles
# seemed so far away.
# Now it looks
# as though they're here to stay.
# Oh, I believe in yesterday.
#
# ...

# %%
# 6-2 formatting1.py
print(1, 2, 3)
print("a" + " " + "b" + " " + "c")
print("%d %d %d" %(1,2,3))
print("{} {} {}".format("a", "b", "c"))
# Out:
# 1 2 3
# a b c
# 1 2 3
# a b c

# %%
# 6-3 formatting2.py
print('%s %s' %('one', 'two'))
print('%d %d' %(1, 2))
# Out:
# one two
# 1 2

# %%
# 6-4 formatting3.py
print("I eat %d apples." %3)
print("I eat %s apples." %"five")
# Out:
# I eat 3 apples.
# I eat five apples.

# %%
# 6-5 formatting4.py
number = 3
day = "three"
print("I ate %d apples. I was sick for %s days." %(number, day))
# Out:
# I ate 3 apples. I was sick for three days.

# %%
# 6-6 formatting5.py
age = 40; name = 'Sungchul Choi'
print("I'm {0} years old.".format(age))
print("My name is {0} and {1} years old.".format(name, age))
print("Product:{0}, Price per unit: {1:.2f}.".format("Apple", 5.243))
# Out:
# I'm 40 years old.
# My name is Sungchul Choi and 40 years old.
# Product:Apple, Price per unit: 5.24.

# %% [markdown]
# ## 연습문제

# %%
# 1
a = 11
b = 9

print('a' + 'b')
print(a + b)
print(str(a) + str(b))
# Out:
# ab
# 20
# 119

# %%
# 2 
fact = "Python is funny"
print(fact.count('n') + fact.find('n') + fact.rfind('n'))
# Out:
# 21

# %%
# 3
text = 'Gachon CS50 - programming with python'
text2 = "Human cs50 knowledge belongs to the world"

text.lower()
print(text[:5] + text[-1] + text[6] + text2.split()[0])
#----------------------------------------------------------
print(text.lower())
text = text.lower()
print(text[:5] + text[-1] + text[6] + text2.split()[0])
# Out:
# Gachon Human
# gachon cs50 - programming with python
# gachon Human

# %%
# 4
class_name = 'introduction programming with python'

for i in class_name:
    if i == 'python':
        i = i.upper()       # 실행되지 않음
        
print(class_name)
# Out:
# introduction programming with python

# %%
# 5
a = '10'
b = '5-2'.split('-')[1]
print(a * 3 + b)
# Out:
# 1010102

# %%
# 6
name = "Hanbit"
a = name.find("H")     # 0
b = name.count("H")*4  # 4
c = len(name) * 2 + 4  # 16
print("REMEMBER", str(a) + str(b) + str(c))
# Out:
# REMEMBER 0416

# %%
# 7
a = "abcd e f g"
b = a.split()
c = (a[:3][0])
d = (b[:3][0][0])
print(c + d)
# Out:
# aa

# %%
# 8
number = 10
day = 3
print("I eat %d oranges every day."%number)

number = 10
day = "three"
print("I eat %d oranges every %s days."%(number,day))
# Out:
# I eat 10 oranges every day.
# I eat 10 oranges every three days.

# %%
# 9
result = "CODE2018"
print("{0},{1}".format(result[-1], result[-2]))
# Out:
# 8,1

# %%
# 10
str_a = "this is"
str_b = "Python"
print(str_a.title(), str_b.upper())
# Out:
# This Is PYTHON

# %%
# 12
print("{0:>6s}".format("*"))
print("{0:>7s}".format("***"))
print("{0:>8s}".format("*****"))
print("{0:>9s}".format("*******"))
print("{0:>10s}".format("*********"))
print("{0:>11s}".format("***********"))
# Out:
#      *
#     ***
#    *****
#   *******
#  *********
# ***********

# %%
# 13
print("{0:>10s}".format("Apple"))  # 10개의 공간, 오른쪽정렬
# vvvvvApple
# Out:
#      Apple

# %%
# 14
# 패딩 (padding) : 여유 공간을 지정하여 글자 배열을 맞추고 소수점 자릿수를 맞추는 서식 지정 기능
#                  % 서식 , format() 함수 모두 패딩 기능 제공

# 네이밍 (naming): 변수명을 서식에 할당할 수 있음 (비순차적)
print("Product: %(name)5s, Price per unit: %(price)5.5f." %{"name":"Apple", "price":5.243})
print("Product: {name:>5s}, Price per unit: {price:5.5f}.".format(name="Apple", price=5.243))
# Out:
# Product: Apple, Price per unit: 5.24300.
# Product: Apple, Price per unit: 5.24300.
